# %%
scout = [
    {
        "name": "Arda",
        "position": "Midfielder",
        "skills": ["Dribbling", "Passing", "Vision"],
        "potential": 90,
        "is_scouted": True
    },
    {
        "name": "Semih",
        "position": "Forward",
        "skills": ["Shooting", "Finishing"],
        "potential": 88,
        "is_scouted": False
    },
    {
        "name": "Kenan",
        "position": "Forward",
        "skills": ["Speed", "Dribbling"],
        "potential": 85,
        "is_scouted": True
    },
    {
        "name": "Arda",
        "position": "Midfielder",
        "skills": ["Dribbling", "Passing", "Vision"],
        "potential": 90,
        "is_scouted": True
    }
]

# %%
toplamOyuncuRaporSayısı = len(scout)

# %%
scoutuTamamlanmis = 0

# %%
scoutuTamamlanmamis = 0

# %%
if scout[0] ["is_scouted"] == True:
    scoutuTamamlanmis += 1
else:
    scoutuTamamlanmamis +=1
if scout[1] ["is_scouted"] == True:
    scoutuTamamlanmis += 1
else:
    scoutuTamamlanmamis +=1
if scout[2] ["is_scouted"] == True:
    scoutuTamamlanmis += 1
else:
    scoutuTamamlanmamis +=1
if scout[3] ["is_scouted"] == True:
    scoutuTamamlanmis += 1
else:
    scoutuTamamlanmamis +=1
print("İzlenmesi tamamlanmış adet :" , scoutuTamamlanmis)
print("İzlenmesi tamamlanmamış adet :" , scoutuTamamlanmamis)
# Out:
# İzlenmesi tamamlanmış adet : 3
# İzlenmesi tamamlanmamış adet : 1

# %%
oyuncuİsimleri = scout[0]["name"],scout[1]["name"],scout[2]["name"],scout[3]["name"]

# %%
print("oyuncu isimleri :" , oyuncuİsimleri)
# Out:
# oyuncu isimleri : ('Arda', 'Semih', 'Kenan', 'Arda')

# %%
temizlenmisOyuncuİsimleri = set(oyuncuİsimleri)

# %%
print("Temizlenmiş oyuncu isimleri :" , temizlenmisOyuncuİsimleri)
# Out:
# Temizlenmiş oyuncu isimleri : {'Semih', 'Arda', 'Kenan'}

# %%
yetenekler = scout[0]["skills"] + scout[1]["skills"] + scout[2]["skills"] + scout[3]["skills"]

# %%
temizlenmişYetenekler = set(yetenekler)

# %%
print("Tüm yetenekler :" , temizlenmişYetenekler)
# Out:
# Tüm yetenekler : {'Dribbling', 'Finishing', 'Speed', 'Shooting', 'Passing', 'Vision'}

# %%
scoutAnaliz0 = (scout[0]["name"],scout[0]["potential"]) 
scoutAnaliz1 = (scout[1]["name"],scout[1]["potential"]) 
scoutAnaliz2 = (scout[2]["name"],scout[2]["potential"]) 
scoutAnaliz3 = (scout[3]["name"],scout[3]["potential"])
analizler = (scoutAnaliz0,scoutAnaliz1,scoutAnaliz2,scoutAnaliz3)
print(analizler)
# Out:
# (('Arda', 90), ('Semih', 88), ('Kenan', 85), ('Arda', 90))
