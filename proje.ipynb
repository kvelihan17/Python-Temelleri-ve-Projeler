# %%
raw_scout_data = "  gEdSoN  fErNaNdEs   |  27 | 1.83 |   gFernandes@bjk.com.TR   "

# %%
futbolcuİsmi , futbolcuYasi , futbolcuBoyu , futbolcuEmail = raw_scout_data.strip().split("|")

# %%
newName = futbolcuİsmi.strip().lower().title()

# %%
newName[:6:] + " " + newName[8:17:]
# Out:
# 'Gedson Fernandes'

# %%
intAge = int(futbolcuYasi.strip())

# %%
emeklilikSüresi = (35 - intAge)

# %%
emeklilikSüresi
# Out:
# 8

# %%
floatBoy = float(futbolcuBoyu.strip()) * 1000

# %%
floatBoy
# Out:
# 1830.0

# %%
temizEmail =futbolcuEmail.lower().strip()

# %%
atİndexi = temizEmail.find("@")

# %%
domainAdres = temizEmail[11::]

# %%
domainAdres
# Out:
# 'bjk.com.tr'
